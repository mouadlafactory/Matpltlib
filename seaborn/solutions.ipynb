# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
tips = sns.load_dataset("tips")
iris = sns.load_dataset("iris")
titanic = sns.load_dataset("titanic")
planets = sns.load_dataset("planets")

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.scatterplot(x="total_bill", y="tip", data=tips)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(x="total_bill", y="tip", data=tips, hue="sex")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(x="total_bill", y="tip", data=tips, hue="day")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(x="total_bill", y="tip", data=tips, hue="day", size="size")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(x="total_bill", y="tip", data=tips, hue="day", size="size", palette="YlGnBu")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(x="total_bill", y="tip", data=tips, hue="day", style="time", size="size")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.histplot(tips["total_bill"])
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
sns.histplot(tips["total_bill"], kde=True)
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
sns.histplot(tips["total_bill"], kde=True, bins=15)
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
sns.kdeplot(tips["total_bill"], shade=True)
# Out:
# /var/folders/5b/bxq2ss215rsc04zk7_vw1lrr0000gn/T/ipykernel_15279/1176046371.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(tips["total_bill"], shade=True)
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
sns.barplot(x="sex", y="tip", data=tips , palette="YlGnBu")
# Out:
# /var/folders/5b/bxq2ss215rsc04zk7_vw1lrr0000gn/T/ipykernel_15279/633807348.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="sex", y="tip", data=tips , palette="YlGnBu")
# <Axes: xlabel='sex', ylabel='tip'>

# %%
sns.barplot(x="day", y="total_bill", data=tips, palette="YlGnBu")
# Out:
# /var/folders/5b/bxq2ss215rsc04zk7_vw1lrr0000gn/T/ipykernel_15279/911951100.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="day", y="total_bill", data=tips, palette="YlGnBu")
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.barplot(x="day", y="total_bill", hue="sex", data=tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.countplot(x="day", data=tips, palette="YlGnBu")
# Out:
# /var/folders/5b/bxq2ss215rsc04zk7_vw1lrr0000gn/T/ipykernel_15279/1824409417.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x="day", data=tips, palette="YlGnBu")
# <Axes: xlabel='day', ylabel='count'>

# %%
sns.countplot(x="day", hue="sex", data=tips, palette="YlGnBu")
# Out:
# <Axes: xlabel='day', ylabel='count'>

# %%
sns.boxplot(x="day", y="total_bill", data=tips, palette="YlGnBu")
# Out:
# /var/folders/5b/bxq2ss215rsc04zk7_vw1lrr0000gn/T/ipykernel_15279/1296625289.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="day", y="total_bill", data=tips, palette="YlGnBu")
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.boxplot(x="day", y="tip", data=tips, palette="YlGnBu")
# Out:
# /var/folders/5b/bxq2ss215rsc04zk7_vw1lrr0000gn/T/ipykernel_15279/612669139.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="day", y="tip", data=tips, palette="YlGnBu")
# <Axes: xlabel='day', ylabel='tip'>

# %%
sns.boxplot(x="day", y="tip", hue="sex", data=tips, palette="YlGnBu")
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
sns.boxplot(x=tips["total_bill"])
# Out:
# <Axes: xlabel='total_bill'>

# %%
sns.stripplot(x="day", y="tip", data=tips, hue="sex", palette="YlGnBu")
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
sns.stripplot(x="day", y="tip", data=tips, hue="sex", palette="YlGnBu", dodge=True)
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
sns.violinplot(x="day", y="total_bill", data=tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(x="day", y="total_bill", hue="sex", data=tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.swarmplot(x="day", y="total_bill", data=tips , palette="YlGnBu" , hue="sex" , dodge=True)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.jointplot(x="tip", y="total_bill", data=tips , palette="YlGnBu")

# %%
sns.jointplot(x="tip", y="total_bill", data=tips, kind="reg")

# %%
sns.jointplot(x="tip", y="total_bill", data=tips, kind="hex", cmap="YlGnBu")

# %%
sns.jointplot(x="tip", y="total_bill", data=tips ,kind="scatter" , hue="sex")

# %%
sns.jointplot(x="tip", y="total_bill", data=tips ,kind="kde", hue="sex")

# %%
sns.jointplot(x="tip", y="total_bill", data=tips ,kind="kde", hue="sex", shade=True)
# Out:
# /Users/newuser/Desktop/gen-ai/gen_ai_machine_learning_bootcamp/gen_ai_machine_learning/py/matpltlib/venv/lib/python3.13/site-packages/seaborn/axisgrid.py:1832: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   func(x=self.x, y=self.y, **kwargs)

# %%
sns.jointplot(x="tip", y="total_bill", data=tips ,kind="kde", shade=True, cmap="YlGnBu")
# Out:
# /Users/newuser/Desktop/gen-ai/gen_ai_machine_learning_bootcamp/gen_ai_machine_learning/py/matpltlib/venv/lib/python3.13/site-packages/seaborn/axisgrid.py:1832: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   func(x=self.x, y=self.y, **kwargs)

# %%
titanic_numeric = titanic.select_dtypes(include=["float64", "int64"])
sns.pairplot(titanic_numeric, hue="pclass")

# %%
sns.pairplot(titanic[["age", "fare", "pclass"]], hue="pclass")

# %%
corr = titanic_numeric.corr()
corr
# Out:
#           survived    pclass       age     sibsp     parch      fare
# survived  1.000000 -0.338481 -0.077221 -0.035322  0.081629  0.257307
# pclass   -0.338481  1.000000 -0.369226  0.083081  0.018443 -0.549500
# age      -0.077221 -0.369226  1.000000 -0.308247 -0.189119  0.096067
# sibsp    -0.035322  0.083081 -0.308247  1.000000  0.414838  0.159651
# parch     0.081629  0.018443 -0.189119  0.414838  1.000000  0.216225
# fare      0.257307 -0.549500  0.096067  0.159651  0.216225  1.000000

# %%
sns.heatmap(corr)
# Out:
# <Axes: >

# %%
sns.heatmap(corr, annot=True)
# Out:
# <Axes: >

# %%
plt.figure(figsize=(10,6))
sns.heatmap(corr, annot=True)
plt.show()

# %%
sns.heatmap(corr, annot=True, cmap="YlGnBu")
# Out:
# <Axes: >

# %%
sns.heatmap(corr, annot=True, cmap="coolwarm")
# Out:
# <Axes: >

# %%
sns.heatmap(corr, annot=True, cmap="icefire")
# Out:
# <Axes: >
